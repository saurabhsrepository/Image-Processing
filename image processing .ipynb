# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('C:/Users/Saurabh/Downloads/goku.jfif')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %%
print(img)
# Out:
# [[[36 34 35]
#   [36 34 35]
#   [36 34 35]
#   ...
#   [ 8  8 10]
#   [ 8  8 10]
#   [ 8  8 10]]
#
#  [[36 34 35]
#   [36 34 35]
#   [36 34 35]
#   ...
#   [ 8  8 10]
#   [ 8  8 10]
#   [ 8  8 10]]
#
#  [[36 34 35]
#   [36 34 35]
#   [36 34 35]
#   ...
#   [ 8  8 10]
#   [ 8  8 10]
#   [ 8  8 10]]
#
#  ...
#
#  [[36 34 35]
#   [36 34 35]
#   [36 34 35]
#   ...
#   [80 82 81]
#   [62 64 63]
#   [51 53 52]]
#
#  [[36 34 35]
#   [36 34 35]
#   [36 34 35]
#   ...
#   [81 81 81]
#   [57 57 57]
#   [40 40 40]]
#
#  [[36 34 35]
#   [36 34 35]
#   [36 34 35]
#   ...
#   [27 27 27]
#   [28 28 28]
#   [33 33 33]]]

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('C:/Users/Saurabh/Downloads/goku.jfif')
img_resized = img.resize((300, 300))

# %%
img_resized.save('goku_resized.jpg')

# %%
img_res = mpimg.imread('C:/Users/Saurabh/goku_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (300, 300, 3)

# %%
import cv2

# %%
img = cv2.imread('C:/Users/Saurabh/goku_resized.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (300, 300, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (300, 300)

# %%
grayscale_image_plot = plt.imshow(grayscale_image , cmap='gray')
plt.show()

# %%
plt.imshow(grayscale_image, cmap='gray')

# %%
cv2.imshow("test" ,grayscale_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('goku_grayscale_image.jpg', grayscale_image)
# Out:
# True
